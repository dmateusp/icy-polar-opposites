# %%
import pandas as pd

# %%
# source: https://n5eil01u.ecs.nsidc.org/DP4/ICEBRIDGE/IGGRV1B.001/2014.11.22/IGGRV1B_20141122_11422600_V016.txt
# date: 2014-11-22T11:42:26Z to 2014-11-23T00:19:05Z
df_1 = pd.read_csv("../data/IGGRV1B_20141122_11422600_V016.txt", comment='#', delim_whitespace=True)

# %%
df_1.head()
# Out:
#          LAT       LONG      DATE  DOY     TIME  FLT         PSX         PSY  \
# 0 -53.004553 -70.845650  20141122  326  42146.0  522 -3929448.42  1364869.24
# 1 -53.004553 -70.845650  20141122  326  42146.5  522 -3929448.40  1364869.24
# 2 -53.004554 -70.845650  20141122  326  42147.0  522 -3929448.38  1364869.22
# 3 -53.004554 -70.845651  20141122  326  42147.5  522 -3929448.36  1364869.21
# 4 -53.004554 -70.845651  20141122  326  42148.0  522 -3929448.33  1364869.20
#
#    WGSHGT    FX    FY         FZ  EOTGRAV  FACOR  INTCOR  FAG070  FAG100  \
# 0   50.15  2.03  2.91  981296.66      NaN    NaN     NaN     NaN     NaN
# 1   50.16  2.24  2.29  981296.95      NaN    NaN     NaN     NaN     NaN
# 2   50.16  3.00  1.93  981297.26      NaN    NaN     NaN     NaN     NaN
# 3   50.16  3.93  2.01  981297.39      NaN    NaN     NaN     NaN     NaN
# 4   50.16  4.61  2.44  981297.24      NaN    NaN     NaN     NaN     NaN
#
#    FAG140  FLTENVIRO
# 0     NaN         -1
# 1     NaN         -1
# 2     NaN         -1
# 3     NaN         -1
# 4     NaN         -1

# %%
df_confirmed_data = df_1[df_1['FLTENVIRO'] == 0]
df_confirmed_data.head()
# Out:
#             LAT       LONG      DATE  DOY     TIME  FLT         PSX  \
# 9219 -53.113036 -70.933760  20141122  326  46755.5  522 -3919206.16
# 9220 -53.113503 -70.933209  20141122  326  46756.0  522 -3919140.06
# 9221 -53.113971 -70.932657  20141122  326  46756.5  522 -3919073.85
# 9222 -53.114439 -70.932104  20141122  326  46757.0  522 -3919007.48
# 9223 -53.114909 -70.931550  20141122  326  46757.5  522 -3918940.94
#
#              PSY   WGSHGT        FX        FY         FZ  EOTGRAV   FACOR  \
# 9219  1354561.13  1759.89 -18632.95 -40848.38  908527.64  -609.23  542.68
# 9220  1354580.48  1762.76 -18721.43 -47234.06  882070.87  -765.59  543.57
# 9221  1354599.85  1765.39 -18936.33 -53345.99  863665.66  -845.74  544.38
# 9222  1354619.26  1767.73 -19714.64 -58528.23  854739.16  -845.87  545.10
# 9223  1354638.69  1769.75 -21445.33 -62462.80  854421.13  -796.82  545.72
#
#       INTCOR  FAG070  FAG100  FAG140  FLTENVIRO
# 9219     0.0  -11.74  -11.20  -11.14          0
# 9220     0.0  -11.92  -11.34  -11.27          0
# 9221     0.0  -12.09  -11.48  -11.41          0
# 9222     0.0  -12.26  -11.62  -11.54          0
# 9223     0.0  -12.42  -11.76  -11.68          0

# %%
df_confirmed_data = df_confirmed_data[['LAT', 'LONG', 'DATE', 'FAG100']]
df_confirmed_data.head()
# Out:
#             LAT       LONG      DATE  FAG100
# 9219 -53.113036 -70.933760  20141122  -11.20
# 9220 -53.113503 -70.933209  20141122  -11.34
# 9221 -53.113971 -70.932657  20141122  -11.48
# 9222 -53.114439 -70.932104  20141122  -11.62
# 9223 -53.114909 -70.931550  20141122  -11.76

# %%
df_confirmed_data['DATE'] = pd.to_datetime(df_confirmed_data['DATE'].apply(str), format='%Y%m%d')
df_confirmed_data['DATE'].head()
# Out:
# 9219   2014-11-22
# 9220   2014-11-22
# 9221   2014-11-22
# 9222   2014-11-22
# 9223   2014-11-22
# Name: DATE, dtype: datetime64[ns]

# %%
df_confirmed_data.head()  # done
# Out:
#             LAT       LONG       DATE  FAG100
# 9219 -53.113036 -70.933760 2014-11-22  -11.20
# 9220 -53.113503 -70.933209 2014-11-22  -11.34
# 9221 -53.113971 -70.932657 2014-11-22  -11.48
# 9222 -53.114439 -70.932104 2014-11-22  -11.62
# 9223 -53.114909 -70.931550 2014-11-22  -11.76

# %%
df_confirmed_data.head().to_json()
# Out:
# '{"LAT":{"9219":-53.1130361,"9220":-53.1135029,"9221":-53.1139706,"9222":-53.1144394,"9223":-53.1149094},"LONG":{"9219":-70.9337602,"9220":-70.9332092,"9221":-70.9326573,"9222":-70.9321043,"9223":-70.9315501},"DATE":{"9219":1416614400000,"9220":1416614400000,"9221":1416614400000,"9222":1416614400000,"9223":1416614400000},"FAG100":{"9219":-11.2,"9220":-11.34,"9221":-11.48,"9222":-11.62,"9223":-11.76}}'
